# %%
# !pip install image-classifiers
# Out:
# Collecting image-classifiers
#   Downloading https://files.pythonhosted.org/packages/8d/7f/31234ee4bc8243f9e8b59b827e8a61436d7269cf75936b0aecc48a08f06c/image_classifiers-0.2.2-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 19.3MB/s
# Requirement already satisfied: keras>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from image-classifiers) (2.2.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (2.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (1.16.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (1.3.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers) (1.1.0)
# Installing collected packages: image-classifiers
# Successfully installed image-classifiers-0.2.2

# %%
import os
import matplotlib
import pandas as pd
from scipy import ndimage
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import io
import glob
import six
import keras
import imgaug as ia
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image
from imgaug import augmenters as iaa
from sklearn import preprocessing
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Model
from keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Dropout,
    GlobalAveragePooling2D
)
from keras.layers.convolutional import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    SeparableConv2D
)
from keras.layers.merge import concatenate, add
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras import backend as K
from keras.utils import np_utils
from keras.optimizers import Adam, SGD
from keras.callbacks import *
from keras.activations import softmax
from keras.models import load_model, Model

# %matplotlib inline

NUM_CLASSES = 200
NUM_IMAGES_PER_CLASS = 500
NUM_IMAGES = NUM_CLASSES * NUM_IMAGES_PER_CLASS
BASE_IMAGE_PATH = 'tiny-imagenet-200'
TRAINING_IMAGES_DIR = 'tiny-imagenet-200/train/'
TRAIN_SIZE = NUM_IMAGES

NUM_TRAIN_IMAGES = 100000
NUM_VAL_IMAGES = 10000
VAL_IMAGES_DIR = 'tiny-imagenet-200/val/'

IMAGE_SIZE = 64
NUM_CHANNELS = 3
IMAGE_ARR_SIZE = IMAGE_SIZE * IMAGE_SIZE * NUM_CHANNELS
SEED_NUM = 42
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive

def fetch_data():
  if not os.path.isdir('tiny-imagenet-200'):
    os.system('wget http://cs231n.stanford.edu/tiny-imagenet-200.zip')
    os.system('unzip -qq tiny-imagenet-200.zip')


def reset_graph(seed):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

reset_graph(seed=SEED_NUM)
# drive.mount('/content/gdrive')
fetch_data()

# %%
from classification_models.resnet import ResNet18, preprocess_input

# %%
def get_model():
  base_model = ResNet18(input_shape=(64,64,3), weights='imagenet', include_top=False)
    
  x = Conv2D(NUM_CLASSES, (1, 1), use_bias=False, activation='softmax')(base_model.output)
  output = GlobalAveragePooling2D()(x)

  model = Model(inputs=[base_model.input], outputs=[output])
  model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
  
  print(model.summary())
  
  return model

# %%
def get_generators(batch_size_train, batch_size_val, no_aug=False, 
                   img_size_train=(64,64), img_size_val=(64,64)):
  val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
  val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
  
  train_datagen = ImageDataGenerator(
      rescale= 1./255,
      preprocessing_function=preprocess_input,
      featurewise_center=True
  )
  train_datagen.mean = np.array([123.68, 116.779, 103.939], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B]


  valid_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=preprocess_input,featurewise_center=True)
  valid_datagen.mean = np.array([123.68, 116.779, 103.939], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B]

  
  train_generator = train_datagen.flow_from_directory(
    r'./tiny-imagenet-200/train/', 
    target_size=img_size_train, 
    color_mode='rgb',
    batch_size=batch_size_train, 
    class_mode='categorical', 
    shuffle=True, 
    seed=SEED_NUM
  )
  train_generator_final = train_generator
    
  validation_generator = valid_datagen.flow_from_dataframe(
      val_data, 
      directory='./tiny-imagenet-200/val/images/', 
      x_col='File', y_col='Class', 
      target_size=img_size_val,
      color_mode='rgb', 
      class_mode='categorical', 
      batch_size=batch_size_val, 
      shuffle=True, 
      seed=SEED_NUM
  )
  
  return train_generator_final, validation_generator

# %%
# Get data
BATCH_SIZE_TRAIN = 128
BATCH_SIZE_VAL = 128
train_generator, validation_generator = get_generators(BATCH_SIZE_TRAIN, BATCH_SIZE_VAL, img_size_train=(64,64), img_size_val=(64,64))
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 validated image filenames belonging to 200 classes.

# %%
model = get_model()

from keras.callbacks import *
checkpoint = ModelCheckpoint('model.h5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

model.fit_generator(train_generator,
                    steps_per_epoch=NUM_TRAIN_IMAGES // BATCH_SIZE_TRAIN,
                    validation_data=validation_generator,
                    validation_steps=NUM_VAL_IMAGES // BATCH_SIZE_VAL,
                    callbacks=[checkpoint],
                    epochs=15)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 64, 64, 3)    9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_163 (ZeroPadding (None, 70, 70, 3)    0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 32, 32, 64)   9408        zero_padding2d_163[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 32, 32, 64)   256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 32, 32, 64)   0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_164 (ZeroPadding (None, 34, 34, 64)   0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 16, 16, 64)   0           zero_padding2d_164[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 16, 16, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 16, 16, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_165 (ZeroPadding (None, 18, 18, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 16, 16, 64)   36864       zero_padding2d_165[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 16, 16, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 16, 16, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_166 (ZeroPadding (None, 18, 18, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 16, 16, 64)   36864       zero_padding2d_166[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 16, 16, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 16, 16, 64)   0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 16, 16, 64)   256         add_73[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 16, 16, 64)   0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_167 (ZeroPadding (None, 18, 18, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 16, 16, 64)   36864       zero_padding2d_167[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 16, 16, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 16, 16, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_168 (ZeroPadding (None, 18, 18, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 16, 16, 64)   36864       zero_padding2d_168[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 16, 16, 64)   0           stage1_unit2_conv2[0][0]
#                                                                  add_73[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 16, 16, 64)   256         add_74[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 16, 16, 64)   0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_169 (ZeroPadding (None, 18, 18, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 8, 8, 128)    73728       zero_padding2d_169[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 8, 8, 128)    512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 8, 8, 128)    0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_170 (ZeroPadding (None, 10, 10, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 8, 8, 128)    147456      zero_padding2d_170[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 8, 8, 128)    8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 8, 8, 128)    0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 8, 8, 128)    512         add_75[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 8, 8, 128)    0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_171 (ZeroPadding (None, 10, 10, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 8, 8, 128)    147456      zero_padding2d_171[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 8, 8, 128)    512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 8, 8, 128)    0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_172 (ZeroPadding (None, 10, 10, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 8, 8, 128)    147456      zero_padding2d_172[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 8, 8, 128)    0           stage2_unit2_conv2[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 8, 8, 128)    512         add_76[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 8, 8, 128)    0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_173 (ZeroPadding (None, 10, 10, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 4, 4, 256)    294912      zero_padding2d_173[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 4, 4, 256)    1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 4, 4, 256)    0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_174 (ZeroPadding (None, 6, 6, 256)    0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 4, 4, 256)    589824      zero_padding2d_174[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 4, 4, 256)    32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 4, 4, 256)    0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 4, 4, 256)    1024        add_77[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 4, 4, 256)    0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_175 (ZeroPadding (None, 6, 6, 256)    0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 4, 4, 256)    589824      zero_padding2d_175[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 4, 4, 256)    1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 4, 4, 256)    0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_176 (ZeroPadding (None, 6, 6, 256)    0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 4, 4, 256)    589824      zero_padding2d_176[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 4, 4, 256)    0           stage3_unit2_conv2[0][0]
#                                                                  add_77[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 4, 4, 256)    1024        add_78[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 4, 4, 256)    0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_177 (ZeroPadding (None, 6, 6, 256)    0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 2, 2, 512)    1179648     zero_padding2d_177[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 2, 2, 512)    2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 2, 2, 512)    0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_178 (ZeroPadding (None, 4, 4, 512)    0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 2, 2, 512)    2359296     zero_padding2d_178[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 2, 2, 512)    131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 2, 2, 512)    0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 2, 2, 512)    2048        add_79[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 2, 2, 512)    0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_179 (ZeroPadding (None, 4, 4, 512)    0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 2, 2, 512)    2359296     zero_padding2d_179[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 2, 2, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 2, 2, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_180 (ZeroPadding (None, 4, 4, 512)    0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 2, 2, 512)    2359296     zero_padding2d_180[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 2, 2, 512)    0           stage4_unit2_conv2[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 2, 2, 512)    2048        add_80[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 2, 2, 512)    0           bn1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 2, 2, 200)    102400      relu1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 200)          0           conv2d_8[0][0]
# ==================================================================================================
# Total params: 11,289,289
# Trainable params: 11,281,347
# Non-trainable params: 7,942
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 781/781 [==============================] - 66s 85ms/step - loss: 3.9041 - acc: 0.2074 - val_loss: 2.8219 - val_acc: 0.3570
#
# Epoch 00001: val_acc improved from -inf to 0.35697, saving model to model.h5
# Epoch 2/15
# 781/781 [==============================] - 60s 77ms/step - loss: 2.4523 - acc: 0.4249 - val_loss: 2.3932 - val_acc: 0.4370
#
# Epoch 00002: val_acc improved from 0.35697 to 0.43699, saving model to model.h5
# Epoch 3/15
# 781/781 [==============================] - 59s 76ms/step - loss: 2.0291 - acc: 0.5069 - val_loss: 2.2245 - val_acc: 0.4695
#
# Epoch 00003: val_acc improved from 0.43699 to 0.46951, saving model to model.h5
# Epoch 4/15
# 781/781 [==============================] - 60s 76ms/step - loss: 1.7379 - acc: 0.5688 - val_loss: 2.1381 - val_acc: 0.4864
#
# Epoch 00004: val_acc improved from 0.46951 to 0.48643, saving model to model.h5
# Epoch 5/15
# 781/781 [==============================] - 59s 75ms/step - loss: 1.5125 - acc: 0.6190 - val_loss: 2.1136 - val_acc: 0.4951
#
# Epoch 00005: val_acc improved from 0.48643 to 0.49514, saving model to model.h5
# Epoch 6/15
# 781/781 [==============================] - 59s 75ms/step - loss: 1.3122 - acc: 0.6672 - val_loss: 2.1047 - val_acc: 0.5015
#
# Epoch 00006: val_acc improved from 0.49514 to 0.50152, saving model to model.h5
# Epoch 7/15
# 781/781 [==============================] - 59s 76ms/step - loss: 1.1268 - acc: 0.7136 - val_loss: 2.1077 - val_acc: 0.4938
#
# Epoch 00007: val_acc did not improve from 0.50152
# Epoch 8/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.9577 - acc: 0.7593 - val_loss: 2.1515 - val_acc: 0.4989
#
# Epoch 00008: val_acc did not improve from 0.50152
# Epoch 9/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.8086 - acc: 0.8017 - val_loss: 2.1650 - val_acc: 0.5010
#
# Epoch 00009: val_acc did not improve from 0.50152
# Epoch 10/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6735 - acc: 0.8408 - val_loss: 2.1985 - val_acc: 0.5018
#
# Epoch 00010: val_acc improved from 0.50152 to 0.50182, saving model to model.h5
# Epoch 11/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.5462 - acc: 0.8777 - val_loss: 2.2501 - val_acc: 0.4969
#
# Epoch 00011: val_acc did not improve from 0.50182
# Epoch 12/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.4445 - acc: 0.9072 - val_loss: 2.2741 - val_acc: 0.4968
#
# Epoch 00012: val_acc did not improve from 0.50182
# Epoch 13/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.3593 - acc: 0.9320 - val_loss: 2.3698 - val_acc: 0.4932
#
# Epoch 00013: val_acc did not improve from 0.50182
# Epoch 14/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.2887 - acc: 0.9511 - val_loss: 2.3499 - val_acc: 0.4968
#
# Epoch 00014: val_acc did not improve from 0.50182
# Epoch 15/15
# 781/781 [==============================] - 59s 76ms/step - loss: 0.2294 - acc: 0.9670 - val_loss: 2.4137 - val_acc: 0.4891
#
# Epoch 00015: val_acc did not improve from 0.50182

# %%
model = load_model('model.h5')

# %%
def get_generator_predictions(batch_size_val=128, img_size_val=(64,64)):
  val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
  val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
  valid_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=preprocess_input,featurewise_center=True)
  valid_datagen.mean = np.array([123.68, 116.779, 103.939], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B]
  validation_generator = valid_datagen.flow_from_dataframe(
        val_data, 
        directory='./tiny-imagenet-200/val/images/', 
        x_col='File', y_col='Class', 
        target_size=img_size_val,
        color_mode='rgb', 
        class_mode='categorical', 
        batch_size=batch_size_val, 
        shuffle=False, 
        seed=SEED_NUM
    )
  return validation_generator

def get_wrong_predictions(labels, predictions, count):
  a=np.array(labels)
  b=np.array(predictions)
  return np.where(a!=b)[0][:count]

def get_imgs_by_idxs(generator, idxs):
  gen_len = len(generator)
  imgs = []
  for idx in idxs:
    batch_idx = (idx // gen_len)
    small_idx = idx - batch_idx*gen_len
    img = generator[batch_idx][0][small_idx]
    imgs.append(img)
    
  imgs = np.array(imgs)
  return imgs
  
def humanize_labels(validation_generator):
  label_file = open('tiny-imagenet-200/words.txt')
  label_text_mapping = dict()
  for line in label_file.readlines():
    label, text = line.split('\t')
    text = text.strip()
    label_text_mapping[label] = text
    
  d = dict(validation_generator.class_indices)
  human_labels = {v: label_text_mapping[k] for k, v in d.items()}
  return human_labels

# %%
def get_img_from_features(x):
  return np.uint8((x + [123.68, 116.779, 103.939]) * 255)

def gradCam(model, img, layer_name, heatmap_opacity=0.4):
  x = np.expand_dims(img, axis=0)
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer(layer_name)
  
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  
  for i in range(len(pooled_grads_value)):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  
  img = get_img_from_features(img)
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    
  superimposed_img = cv2.addWeighted(img, 1-heatmap_opacity, heatmap, heatmap_opacity, 0)
  
  return img, superimposed_img
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide

# %%
human_labels = humanize_labels(validation_generator)

validation_generator = get_generator_predictions()
predictions = model.predict_generator(validation_generator, steps=len(validation_generator))
predicted_classes = np.argmax(predictions, axis=1)

wrong_idxs = get_wrong_predictions(validation_generator.labels, predicted_classes, 50)
wrong_imgs = get_imgs_by_idxs(validation_generator, wrong_idxs)


imgs = []
superimposed_imgs = []

for w_img in wrong_imgs:
  img, superimposed_img = gradCam(model, w_img, layer_name="stage4_unit2_conv2")
  imgs.append(img)
  superimposed_imgs.append(superimposed_img)
# Out:
# (50, 50)

# %%
plot_x = 5
plot_y = 10
fig, ax = plt.subplots(plot_x, plot_y, figsize = (30, 30))

for i in range(plot_y):
  for j in range(plot_x):
    idx = i*plot_x + j
    val_idx = wrong_idxs[idx]
    
    true_class = human_labels[validation_generator.labels[val_idx]][:20]
    pred_class = human_labels[predicted_classes[val_idx]][:20]
    ax[j, i].imshow(superimposed_imgs[idx])
    ax[j, i].set_title('True: {}\nPred: {}'.format(str(true_class), str(pred_class)))
